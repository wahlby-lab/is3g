# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import seaborn as sns
import os
import sys
module_path = os.path.abspath(os.path.join('..','isseg'))
sys.path.insert(0, module_path)
from isseg import isseg

# Load the data
df = pd.read_csv('data.csv')
cluster = isseg(df, x='X', y='Y', label='Gene', radius=22.5)
df['Result'] = pd.Categorical(cluster)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Training on device: cpu
#   0%|          | 0/500 [00:00<?, ?it/s]
# Stopping early at epoch 221 with loss 0.4128

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, sharex=True, sharey=True, figsize=(20,10))
sns.scatterplot(df, x='X', y='Y', hue='Gene', ax=axs[0], legend=False)
sns.scatterplot(df, x='X', y='Y', hue='Result', ax=axs[1], legend=False)

axs[0].set_title('Genes')
axs[1].set_title('Segmentation')
# Out:
# Text(0.5, 1.0, 'Segmentation')
